# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key

from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['aquiraz',
#  'saint-philippe',
#  'puerto ayora',
#  'punta arenas',
#  'pelym',
#  'arraial do cabo',
#  'uberaba',
#  'christchurch',
#  'hilo',
#  'port alfred',
#  'torbay',
#  'zhuhai',
#  'sur',
#  'atuona',
#  'mataura',
#  'coahuayana',
#  'east london',
#  'tsihombe',
#  'clyde river',
#  'roma',
#  'havre-saint-pierre',
#  'auki',
#  'new norfolk',
#  'ushuaia',
#  'kodiak',
#  'margate',
#  'pisco',
#  'bilma',
#  'hakkari',
#  'pevek',
#  'cape town',
#  'rikitea',
#  'busselton',
#  'eagle pass',
#  'te anau',
#  'murray bridge',
#  'hermanus',
#  'jambusar',
#  'bardiyah',
#  'sangar',
#  'gurupa',
#  'muros',
#  'leningradskiy',
#  'upernavik',
#  'boissevain',
#  'surt',
#  'yerbogachen',
#  'verdun',
#  'castro',
#  'faanui',
#  'norman wells',
#  'gigmoto',
#  'lana',
#  'mar del plata',
#  'mirebalais',
#  'hobart',
#  'carnarvon',
#  'bredasdorp',
#  'vaitupu',
#  'vanimo',
#  'bambous virieux',
#  'vaini',
#  'saint-pierre',
#  'opuwo',
#  'qaanaaq',
#  'moose factory',
#  'pauini',
#  'bluff',
#  'albany',
#  'port hueneme',
#  'walvis bay',
#  'ballina',
#  'san patricio',
#  'huambo',
#  'altamira',
#  'vredendal',
#  'salihorsk',
#  'norwich',
#  'harrison',
#  'mentok',
#  'chuy',
#  'ponta do sol',
#  'tuatapere',
#  'jardim',
#  'vardo',
#  'attawapiskat',
#  'saskylakh',
#  'chaplynka',
#  'meulaboh',
#  'belmonte',
#  'nome',
#  'hirara',
#  'kalikapur',
#  'saint george',
#  'hambantota',
#  'mehamn',
#  'chokurdakh',
#  'jamestown',
#  'tiksi',
#  'grand gaube',
#  'devils lake',
#  'laiagam',
#  'tuktoyaktuk',
#  'ulladulla',
#  'lorengau',
#  'kushima',
#  'lompoc',
#  'lac du bonnet',
#  'nambucca heads',
#  'cayenne',
#  'marfino',
#  'mys shmidta',
#  'fortuna',
#  'taoudenni',
#  'sorland',
#  'yagodnoye',
#  'barentsburg',
#  'sao miguel',
#  'malakal',
#  'elat',
#  'hihifo',
#  'fort saint john',
#  'amderma',
#  'alice springs',
#  'hamilton',
#  'arman',
#  'illoqqortoormiut',
#  'vestmannaeyjar',
#  'palabuhanratu',
#  'fayaoue',
#  'butaritari',
#  'pangnirtung',
#  'hithadhoo',
#  'zyryanka',
#  'avarua',
#  'kirksville',
#  'yangcun',
#  'byron bay',
#  'saleaula',
#  'douentza',
#  'vila franca do campo',
#  'manzhouli',
#  'dumas',
#  'acarau',
#  'pachino',
#  'nikolskoye',
#  'ewo',
#  'thalgau',
#  'puerto del rosario',
#  'nianzishan',
#  'yancheng',
#  'nabire',
#  'tasiilaq',
#  'mahebourg',
#  'vestmanna',
#  'georgetown',
#  'thompson',
#  'yellowknife',
#  'iqaluit',
#  'whitehorse',
#  'celestun',
#  'solnechnyy',
#  'krasnogorsk',
#  'baykit',
#  'abengourou',
#  'haines junction',
#  'lodja',
#  'taolanaro',
#  'omboue',
#  'mount gambier',
#  'kahului',
#  'la palma',
#  'severo-kurilsk',
#  'belyy yar',
#  'katsuura',
#  'batagay-alyta',
#  'ribeira grande',
#  'bethel',
#  'ahipara',
#  'atambua',
#  'cidreira',
#  'imeni babushkina',
#  'rocha',
#  'voh',
#  'kasongo-lunda',
#  'saint-joseph',
#  'mehran',
#  'esperance',
#  'ivangorod',
#  'porto de moz',
#  'altagracia de orituco',
#  'ikom',
#  'ostrovnoy',
#  'mujiayingzi',
#  'lashma',
#  'shimoda',
#  'fort nelson',
#  'kapaa',
#  'port blair',
#  'puerto escondido',
#  'kavaratti',
#  'samarai',
#  'bafq',
#  'cherskiy',
#  'sioux lookout',
#  'gizo',
#  'mutsamudu',
#  'xuddur',
#  'umzimvubu',
#  'sagua la grande',
#  'aklavik',
#  'namatanai',
#  'manado',
#  'la sarre',
#  'halalo',
#  'port lincoln',
#  'tochimilco',
#  'meybod',
#  'beyneu',
#  'yasnogorsk',
#  'saldanha',
#  'borlange',
#  'bilibino',
#  'zelenoborskiy',
#  'upington',
#  'narsaq',
#  'dumka',
#  'viedma',
#  'ancud',
#  'nanortalik',
#  'talnakh',
#  'ketchikan',
#  'boa vista',
#  'humaita',
#  'tiszacsege',
#  'danilovka',
#  'sao filipe',
#  'pasighat',
#  'alenquer',
#  'gurgan',
#  'barrow',
#  'jining',
#  'souillac',
#  'broome',
#  'port keats',
#  'lavrentiya',
#  'poim',
#  'flinders',
#  'port augusta',
#  'arlit',
#  'romitan',
#  'belushya guba',
#  'peniche',
#  'tiruvottiyur',
#  'samusu',
#  'grand river south east',
#  'kashi',
#  'airai',
#  'le port',
#  'kaoma',
#  'bengkulu',
#  'tevaitoa',
#  'bonthe',
#  'comarapa',
#  'pochutla',
#  'sao joao da barra',
#  'haverfordwest',
#  'la ronge',
#  'yermolayevo',
#  'sobolevo',
#  'olafsvik',
#  'selenginsk',
#  'iquique',
#  'sorong',
#  'teya',
#  'venezuela',
#  'geraldton',
#  'faya',
#  'uray',
#  'gewane',
#  'presidencia roque saenz pena',
#  'xinmin',
#  'akhtubinsk',
#  'los llanos de aridane',
#  'bathsheba',
#  'isangel',
#  'bushehr',
#  'mago',
#  'urumqi',
#  'ossora',
#  'motygino',
#  'mobaye',
#  'maragogi',
#  'san vicente',
#  'remontnoye',
#  'lagoa',
#  'kavieng',
#  'padang',
#  'rantepao',
#  'ingham',
#  'russell',
#  'berlevag',
#  'plaster rock',
#  'ludvika',
#  'elko',
#  'saint-georges',
#  'xam nua',
#  'truth or consequences',
#  'qui nhon',
#  'hofn',
#  'karratha',
#  'antalaha',
#  'galveston',
#  'port elizabeth',
#  'wagar',
#  'gravdal',
#  'lukiv',
#  'nishihara',
#  'kalmunai',
#  'okhotsk',
#  'tarnowskie gory',
#  'sokoto',
#  'hasaki',
#  'dikson',
#  'sola',
#  'neepawa',
#  'nokaneng',
#  'kang',
#  'provideniya',
#  'fare',
#  'cloquet',
#  'tukrah',
#  'nantucket',
#  'nizhneyansk',
#  'ceske velenice',
#  'praia da vitoria',
#  'wolmaranstad',
#  'yar-sale',
#  'sentyabrskiy',
#  'victoria',
#  'college',
#  'potanino',
#  'danville',
#  'den helder',
#  'ohara',
#  'genhe',
#  'puerto leguizamo',
#  'marienburg',
#  'kawalu',
#  'lebu',
#  'krapina',
#  'beringovskiy',
#  'platonovka',
#  'bandar-e torkaman',
#  'bani',
#  'dongsheng',
#  'kalaleh',
#  'ocean city',
#  'najran',
#  'ca mau',
#  'raudeberg',
#  'clinton',
#  'safaqis',
#  'saint-pascal',
#  'brotas',
#  'manokwari',
#  'una',
#  'chicama',
#  'toora-khem',
#  'carauari',
#  'sabha',
#  'odweyne',
#  'bonfim',
#  'barbar',
#  'rawson',
#  'ponta delgada',
#  'salalah',
#  'varhaug',
#  'ust-nera',
#  'klyuchi',
#  'agadez',
#  'nara',
#  'oktyabrskiy',
#  'saint-leu',
#  'bucak',
#  'kuusamo',
#  'port-gentil',
#  'sinnamary',
#  'alekseyevsk',
#  'mouila',
#  'parfenyevo',
#  'emmaus',
#  'longyearbyen',
#  'maraa',
#  'leh',
#  'bo phloi',
#  'amahai',
#  'correderos',
#  'takoradi',
#  'hualmay',
#  'isla mujeres',
#  'mumford',
#  'bom jardim',
#  'rojhan',
#  'asau',
#  'kuppam',
#  'ambulu',
#  'bonavista',
#  'havoysund',
#  'nouakchott',
#  'tabuk',
#  'ekibastuz',
#  'tidore',
#  'harstad',
#  'phangnga',
#  'caravelas',
#  'miri',
#  'bacuit',
#  'scottsbluff',
#  'karasjok',
#  'sitka',
#  'henties bay',
#  'yinchuan',
#  'sirajganj',
#  'yei',
#  'touros',
#  'muncar',
#  'coihaique',
#  'kalabo',
#  'maxixe',
#  'namibe',
#  'pacific grove',
#  'phuket',
#  'bousse',
#  'aflu',
#  'homa bay',
#  'rio gallegos',
#  'kaeo',
#  'vakhsh',
#  'ilulissat',
#  'kaitangata',
#  'ta khmau',
#  'yichang',
#  'luderitz',
#  'aasiaat',
#  'khorixas',
#  'vilyuysk',
#  'morros',
#  'kulhudhuffushi',
#  'morant bay',
#  'nova olimpia',
#  'mandalgovi',
#  'saint-augustin',
#  'wencheng',
#  'stornoway',
#  'paltin',
#  'tsienyane',
#  'varkkallai',
#  'barcelos',
#  'martapura',
#  'ola',
#  'dingle',
#  'pouembout',
#  'bandarbeyla',
#  'labuan',
#  'asosa',
#  'cabo san lucas',
#  'tumannyy',
#  'gualaquiza',
#  'atar',
#  'garowe',
#  'rungata',
#  'bourail',
#  'portlethen',
#  'kruisfontein',
#  'dunedin',
#  'milos',
#  'butzow',
#  'dubasari',
#  'taber',
#  'marystown',
#  'quatre cocos',
#  'zhigansk',
#  'ulaangom',
#  'port macquarie',
#  'barber',
#  'fairbanks',
#  'bijar',
#  'kamaishi',
#  'san cristobal',
#  'mamallapuram',
#  'semnan',
#  'vanavara',
#  'nosivka',
#  'san francisco',
#  'north bend',
#  'alyangula',
#  'avanigadda',
#  'igrim',
#  'cadillac',
#  'pahrump',
#  'knyaze-volkonskoye',
#  'tateyama',
#  'portland',
#  'yumen',
#  'marcona',
#  'batken',
#  'flin flon',
#  'coquimbo',
#  'naze',
#  'afsin',
#  'ust-tsilma',
#  'moroni',
#  'lingao',
#  'amga',
#  'paraiso',
#  'atbasar',
#  'mnogovershinnyy',
#  'gamba',
#  'chirongui',
#  'gribanovskiy',
#  'ginda',
#  'namestovo',
#  'muisne',
#  'dourbali',
#  'moose jaw',
#  'lolua',
#  'komsomolskiy',
#  'gualeguaychu',
#  'krasnoselkup',
#  'baculin',
#  'brownsville',
#  'iralaya',
#  'mogadishu',
#  'marsh harbour',
#  'constitucion',
#  'egvekinot',
#  'san jose pinula',
#  'lata',
#  'potgietersrus',
#  'santiago del estero',
#  'clifton',
#  'novokizhinginsk',
#  'vila',
#  'aripuana',
#  'paita',
#  'nalut',
#  'klaksvik',
#  'palmer',
#  'makasar',
#  'adolfo lopez mateos',
#  'bull savanna',
#  'french harbor',
#  'hammerfest',
#  'dzhusaly',
#  'san quintin',
#  'nioro',
#  'moss point',
#  'sechura',
#  'tura',
#  'qaqortoq',
#  'zhangye',
#  'gat',
#  'victor harbor',
#  'yelan',
#  'sataua',
#  'slave lake',
#  'svetlyy',
#  'mutis',
#  'karakose',
#  'samalaeulu',
#  'awjilah',
#  'bageshwar',
#  'comodoro rivadavia',
#  'tari',
#  'sistranda',
#  'bima',
#  'coutances',
#  'mount isa',
#  'matara',
#  'lillooet',
#  'the valley',
#  'marawi',
#  'sydney',
#  'great falls',
#  'basoko',
#  'berdigestyakh',
#  'iskandar',
#  'tahta',
#  'qasigiannguit',
#  'formoso do araguaia',
#  'sayyan',
#  'san rafael del sur',
#  'mahajanga',
#  'labutta',
#  'dolbeau',
#  'kurud',
#  'inirida',
#  'maceio',
#  'gulariya',
#  'adrar',
#  'kudat',
#  'san ramon',
#  'katherine',
#  'at-bashi',
#  'cozumel',
#  'general roca']

# %%
url="http://api.openweathermap.org/data/2.5/weather?appid="+weather_api_key+"&units=imperial&q="
lats=[]
long=[]
cloud=[]
temp=[]
wind_speed=[]
country=[]
date=[]
humidity=[]
cities_found=[]
cities_notfound=[]
i=1
print("Beginning Data Retrieval")
print("---------------------------------------")

for city in cities:
    query_url=url+city
    response=requests.get(query_url)
    data=response.json()
    time.sleep(2)
    try:
        print(f"Processing Record {i} of Set 1 | {city}")
        i=i+1
        cities_found.append(data["name"])
        country.append(data["sys"]["country"])
        humidity.append(data["main"]["humidity"])
        lats.append(data["coord"]["lat"])
        long.append(data["coord"]["lon"])
        cloud.append(data["clouds"]["all"])
        temp.append(data["main"]["temp_max"])
        wind_speed.append(data["wind"]["speed"])
        date.append(data["dt"])
    
    except Exception:
        print("City not found. Skipping......")
        cities_notfound.append(city)
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | aquiraz
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 
# Processing Record 577 of Set 1 | bima
# Processing Record 578 of Set 1 | coutances
# Processing Record 579 of Set 1 | mount isa
# Processing Record 580 of Set 1 | matara
# Processing Record 581 of Set 1 | lillooet
# Processing Record 582 of Set 1 | the valley
# Processing Record 583 of Set 1 | marawi
# Processing Record 584 of Set 1 | sydney
# Processing Record 585 of Set 1 | great falls
# Processing Record 586 of Set 1 | basoko
# Processing Record 587 of Set 1 | berdigestyakh
# Processing Record 588 of Set 1 | iskandar
# Processing Record 589 of Set 1 | tahta
# Processing Record 590 of Set 1 | qasigiannguit
# Processing Record 591 of Set 1 | formoso do araguaia
# City not found. Skipping......
# Processing Record 592 of Set 1 | sayyan
# Processing Record 593 of Set 1 | san rafael del sur
# Processing Record 594 of Set 1 | mahajanga
# Processing Record 595 of Set 1 | labutta
# City not found. Skipping......
# Processing Record 596 of Set 1 | dolbeau
# City not found. Skipping......
# Processing Record 597 of Set 1 | kurud
# Processing Record 598 of Set 1 | inirida
# Processing Record 599 of Set 1 | maceio
# Processing Record 600 of Set 1 | gulariya
# Processing Record 601 of Set 1 | adrar
# Processing Record 602 of Set 1 | kudat
# Processing Record 603 of Set 1 | san ramon
# Processing Record 604 of Set 1 | katherine
# Processing Record 605 of Set 1 | at-bashi
# Processing Record 606 of Set 1 | cozumel
# Processing Record 607 of Set 1 | general roca

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_found
len(cities_found)
#len(lats)
#len(long)
# Out:
# 561

# %%
cities_df=pd.DataFrame({"City": cities_found,"Cloudiness":cloud,"Country":country,"Date":date,"Humidity":humidity,"Lat":lats,\
                        "Long":long,"Max Temp":temp,"Wind Speed":wind_speed}) 
cities_df.head()
#len(lats)
#len(long)
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat   Long  \
# 0         Aquiraz          20      BR  1583968183        74  -3.90 -38.39
# 1  Saint-Philippe          75      RE  1583967962        94 -21.36  55.77
# 2    Puerto Ayora          20      EC  1583967965        74  -0.74 -90.35
# 3    Punta Arenas          90      CL  1583968135        93 -53.15 -70.92
# 4           Pelym         100      RU  1583968191        92  61.01  62.00
#
#    Max Temp  Wind Speed
# 0     84.20        5.82
# 1     78.80       12.75
# 2     84.20       10.29
# 3     51.80        8.05
# 4     33.76       10.67

# %%
cities_df.to_csv(output_data_file,index=False,header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Max Temp"], facecolor="blue",edgecolor="black")
plt.grid(True)
plt.title("City Latitude vs. Max Temperature (03/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.savefig("output_data/Img1.png")
plt.show()
#This scatter plot shows how the temperature of each city changes with the change is latitude

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Humidity"], facecolor="blue",edgecolor="black")
plt.grid(True)
plt.title("City Latitude vs. Humidity (03/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig("output_data/Img2.png")
plt.show()
#This scatter plot shows the distribution of humidity with respect to the latitude of location of each city.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Cloudiness"], facecolor="blue",edgecolor="black")
plt.grid(True)
plt.title("City Latitude vs. Cloudiness (03/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("output_data/Img3.png")
plt.show()
#This scatter plot shows the cloudiness of city changes with change in latitude location of each city.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Wind Speed"], facecolor="blue",edgecolor="black")
plt.grid(True)
plt.title("City Latitude vs. Wind Speed (03/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/Img4.png")
plt.show()
#This scatter plot shows how wind speed varies with change in latitude location of each city.
#For majority of the cities the wind speed is concentrated between 0 to 25 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-squared is: {rvalue*rvalue}")
    plt.xlabel('Latitude')
    return line_eq

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hem=cities_df.loc[cities_df["Lat"]>=0,:]
Northern_hem=Northern_hem.reset_index(drop=True)
Northern_hem.head()
# Out:
#      City  Cloudiness Country        Date  Humidity    Lat    Long  Max Temp  \
# 0   Pelym         100      RU  1583968191        92  61.01   62.00     33.76
# 1    Hilo          75      US  1583968199        61  19.73 -155.09     80.60
# 2  Torbay          90      CA  1583968204       100  47.67  -52.73     36.00
# 3  Zhuhai          40      CN  1583968206        93  22.28  113.57     68.00
# 4     Sur           0      OM  1583968208        27  22.57   59.53     62.06
#
#    Wind Speed
# 0       10.67
# 1       13.87
# 2       12.75
# 3        9.17
# 4        3.71

# %%
Southern_hem=cities_df.loc[cities_df["Lat"]<0,:]
Southern_hem=Southern_hem.reset_index(drop=True)
Southern_hem.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat   Long  \
# 0          Aquiraz          20      BR  1583968183        74  -3.90 -38.39
# 1   Saint-Philippe          75      RE  1583967962        94 -21.36  55.77
# 2     Puerto Ayora          20      EC  1583967965        74  -0.74 -90.35
# 3     Punta Arenas          90      CL  1583968135        93 -53.15 -70.92
# 4  Arraial do Cabo           0      BR  1583968193        71 -22.97 -42.03
#
#    Max Temp  Wind Speed
# 0     84.20        5.82
# 1     78.80       12.75
# 2     84.20       10.29
# 3     51.80        8.05
# 4     76.68       12.71

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_eq1=linear_regression(Northern_hem["Lat"],Northern_hem["Max Temp"])
plt.annotate(line_eq1,(10,-10),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.7375345248168521

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_eq2=linear_regression(Southern_hem["Lat"],Southern_hem["Max Temp"])
plt.annotate(line_eq2,(-30,50),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.32641741202566404

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_eq3=linear_regression(Northern_hem["Lat"],Northern_hem["Humidity"])
plt.annotate(line_eq3,(40,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.08223239499604777

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_eq4=linear_regression(Southern_hem["Lat"],Southern_hem["Humidity"])
plt.annotate(line_eq4,(-30,50),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.08106416967292274

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_eq5=linear_regression(Northern_hem["Lat"],Northern_hem["Cloudiness"])
plt.annotate(line_eq5,(40,20),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.08743125779596382

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_eq6=linear_regression(Southern_hem["Lat"],Southern_hem["Cloudiness"])
plt.annotate(line_eq6,(-30,20),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.038751564118086876

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_eq5=linear_regression(Northern_hem["Lat"],Northern_hem["Wind Speed"])
plt.annotate(line_eq5,(40,30),fontsize=15,color="red")
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The r-squared is: 0.03706796942105674

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_eq6=linear_regression(Southern_hem["Lat"],Southern_hem["Wind Speed"])
plt.annotate(line_eq6,(-30,20),fontsize=15,color="red")
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The r-squared is: 0.11592848358911846

# %%
#Observations:
#The r-squared value for a linear regression between lati
